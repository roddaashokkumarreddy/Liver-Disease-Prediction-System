# %%
#Importing the necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading the data
data=pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')
data.head()
# Out:
#    65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0  62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1  62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2  58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3  72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4  46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1

# %%
# Size of the dataset
data.shape
# Out:
# (582, 11)

# %%
# Initiate the columns names
columns=['age', 'gender','total_bilirubin','direct_bilirubin','alkaline_phosphotase',
         'alamine_aminotransferase','asparate_aminotransferase','total_protiens',
         'albumin','albumin_and_globulin_ratio','outcome']

# %%
# Assign the columns into the dataset
data.columns=columns

# %%
# Print the top 5 records in the dataset
data.head()
# Out:
#    age gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   62   Male             10.9               5.5                   699
# 1   62   Male              7.3               4.1                   490
# 2   58   Male              1.0               0.4                   182
# 3   72   Male              3.9               2.0                   195
# 4   46   Male              1.8               0.7                   208
#
#    alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 0                        64                        100             7.5
# 1                        60                         68             7.0
# 2                        14                         20             6.8
# 3                        27                         59             7.3
# 4                        19                         14             7.6
#
#    albumin  albumin_and_globulin_ratio  outcome
# 0      3.2                        0.74        1
# ...

# %%
data.shape
# Out:
# (582, 11)

# %%
# This is the  defaut column and adding at last 
new_row=pd.Series({'age': 65, 'gender':'Female', 'total_bilirubin':0.7, 'direct_bilirubin':0.1,
                      'alkaline_phosphotase':187, 'alamine_aminotransferase':16,
                      'asparate_aminotransferase':18, 'total_protiens':6.8, 'albumin':3.3,
                      'albumin_and_globulin_ratio': 0.9, 'outcome': 1})

# %%
data=data.append(new_row, ignore_index=True)

# %%
# Print the last 5 columns 
data.tail()
# Out:
#      age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 578   40    Male              0.6               0.1                    98
# 579   52    Male              0.8               0.2                   245
# 580   31    Male              1.3               0.5                   184
# 581   38    Male              1.0               0.3                   216
# 582   65  Female              0.7               0.1                   187
#
#      alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 578                        35                         31             6.0
# 579                        48                         49             6.4
# 580                        29                         32             6.8
# 581                        21                         24             7.3
# 582                        16                         18             6.8
#
#      albumin  albumin_and_globulin_ratio  outcome
# ...

# %%
data.shape
# Out:
# (583, 11)

# %%
# Assign the indices from 1 to 583 instead of using 0 to 582
data.index=list(range(1,len(data)+1, 1))

# %%
data.head()
# Out:
#    age gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 1   62   Male             10.9               5.5                   699
# 2   62   Male              7.3               4.1                   490
# 3   58   Male              1.0               0.4                   182
# 4   72   Male              3.9               2.0                   195
# 5   46   Male              1.8               0.7                   208
#
#    alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 1                        64                        100             7.5
# 2                        60                         68             7.0
# 3                        14                         20             6.8
# 4                        27                         59             7.3
# 5                        19                         14             7.6
#
#    albumin  albumin_and_globulin_ratio  outcome
# 1      3.2                        0.74        1
# ...

# %%
data.tail()
# Out:
#      age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
# 583   65  Female              0.7               0.1                   187
#
#      alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 579                        35                         31             6.0
# 580                        48                         49             6.4
# 581                        29                         32             6.8
# 582                        21                         24             7.3
# 583                        16                         18             6.8
#
#      albumin  albumin_and_globulin_ratio  outcome
# ...

# %%
# Identify the independent variables and dependent variables
data['outcome'].value_counts()
# Out:
# 1    416
# 2    167
# Name: outcome, dtype: int64

# %%
data['outcome']=data['outcome']-1

# %%
data.head()
# Out:
#    age gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 1   62   Male             10.9               5.5                   699
# 2   62   Male              7.3               4.1                   490
# 3   58   Male              1.0               0.4                   182
# 4   72   Male              3.9               2.0                   195
# 5   46   Male              1.8               0.7                   208
#
#    alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 1                        64                        100             7.5
# 2                        60                         68             7.0
# 3                        14                         20             6.8
# 4                        27                         59             7.3
# 5                        19                         14             7.6
#
#    albumin  albumin_and_globulin_ratio  outcome
# 1      3.2                        0.74        0
# ...

# %%
data['outcome'].value_counts()
# Out:
# 0    416
# 1    167
# Name: outcome, dtype: int64

# %%
# Data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 1 to 583
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         583 non-null    int64
#  1   gender                      583 non-null    object
#  2   total_bilirubin             583 non-null    float64
#  3   direct_bilirubin            583 non-null    float64
#  4   alkaline_phosphotase        583 non-null    int64
#  5   alamine_aminotransferase    583 non-null    int64
#  6   asparate_aminotransferase   583 non-null    int64
#  7   total_protiens              583 non-null    float64
#  8   albumin                     583 non-null    float64
#  9   albumin_and_globulin_ratio  579 non-null    float64
#  10  outcome                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 54.7+ KB

# %%
# Identify the missing values
data.isnull().sum()
# Out:
# age                           0
# gender                        0
# total_bilirubin               0
# direct_bilirubin              0
# alkaline_phosphotase          0
# alamine_aminotransferase      0
# asparate_aminotransferase     0
# total_protiens                0
# albumin                       0
# albumin_and_globulin_ratio    4
# outcome                       0
# dtype: int64

# %%
# Filling the missing values in data['albumin_and_globulin_ratio']
temp=data['albumin_and_globulin_ratio']
temp.replace(np.nan,temp.mean(), inplace=True)

# %%
# Checking the missing values 
data.isnull().sum()
# Out:
# age                           0
# gender                        0
# total_bilirubin               0
# direct_bilirubin              0
# alkaline_phosphotase          0
# alamine_aminotransferase      0
# asparate_aminotransferase     0
# total_protiens                0
# albumin                       0
# albumin_and_globulin_ratio    0
# outcome                       0
# dtype: int64

# %%
# Checking the duplicated  row are there or not
data.duplicated().sum()
# Out:
# 13

# %%
# Drop the duplicated rows
data.drop_duplicates(inplace=True)

# %%
# checking the shape of the dataset
data.shape
# Out:
# (570, 11)

# %% [markdown]
# # **Data Visualization**

# %%
# importing the seaborn package
import seaborn as sns

# %%
data.columns
# Out:
# Index(['age', 'gender', 'total_bilirubin', 'direct_bilirubin',
#        'alkaline_phosphotase', 'alamine_aminotransferase',
#        'asparate_aminotransferase', 'total_protiens', 'albumin',
#        'albumin_and_globulin_ratio', 'outcome'],
#       dtype='object')

# %%
data_desc=data.describe()
data_desc
# Out:
#               age  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# count  570.000000       570.000000        570.000000            570.000000
# mean    44.849123         3.321754          1.497544            291.750877
# std     16.242182         6.267941          2.833231            245.291859
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            176.000000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# count                570.000000                 570.000000      570.000000
# mean                  79.728070                 109.380702        6.496316
# ...

# %%
data['outcome'].value_counts().plot(kind='bar')
plt.xlabel('outcome')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# # **bar plot**

# %%
plt.style.use('ggplot')
data_desc.loc['mean'].plot.bar()
plt.show()

# %% [markdown]
# # Observations
#
# *   In the above ggplot, the features age, alkaline_phosphotase, alamine_aminotransferase, asparate_aminotransferase are more affected to outcome

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(data, diag_kind='kde')
plt.show()

# %%
sns.jointplot(x='total_bilirubin',y='direct_bilirubin', data=data, kind='reg')
plt.show()

# %%
sns.jointplot(x='alamine_aminotransferase', y='asparate_aminotransferase', data=data, kind='reg')
plt.show()

# %%
sns.jointplot(x= 'total_protiens', y='albumin', data=data, kind='reg')

# %%
sns.jointplot(x= 'albumin', y= 'albumin_and_globulin_ratio', data=data, kind='reg')

# %% [markdown]
# # Observations:
#
# *   In the above pair plot, I observed that the features 'total_bilirubin' and 'direct_bilirubin' are linear relationship
# *   And the features 'alamine_aminotransferase' and 'asparate_aminotransferase' are also in linear relationship
# *  The features 'total_protiens' and 'albumin' are also linear relationship
# *   The features 'albumin' and 'albumin_and_globumin_ration' are in linear relationship

# %% [markdown]
# # **Heat Map**

# %%
cormat=data.corr()
cormat
# Out:
#                                  age  total_bilirubin  direct_bilirubin  \
# age                         1.000000         0.011500          0.007050
# total_bilirubin             0.011500         1.000000          0.874116
# direct_bilirubin            0.007050         0.874116          1.000000
# alkaline_phosphotase        0.081673         0.206239          0.234609
# alamine_aminotransferase   -0.083383         0.217471          0.237450
# asparate_aminotransferase  -0.016753         0.238678          0.258489
# total_protiens             -0.197052        -0.008588         -0.000875
# albumin                    -0.271170        -0.224124         -0.230751
# albumin_and_globulin_ratio -0.215633        -0.207621         -0.201386
# outcome                    -0.138093        -0.224430         -0.250666
#
#                             alkaline_phosphotase  alamine_aminotransferase  \
# age                                     0.081673                 -0.083383
# ...

# %%
cormat.shape
# Out:
# (10, 10)

# %%
fig, ax= plt.subplots(figsize=(10,10))
sns.heatmap(cormat, annot=True)
plt.show()

# %%
#identify the skew features and print the ascending order
num_features=data.dtypes[data.dtypes!='object'].index
skew_features=data[num_features].skew().sort_values(ascending=False)
skew_features
# Out:
# asparate_aminotransferase     10.559418
# alamine_aminotransferase       6.695054
# total_bilirubin                4.869459
# alkaline_phosphotase           3.728405
# direct_bilirubin               3.187685
# albumin_and_globulin_ratio     1.004870
# outcome                        0.940320
# age                           -0.046597
# albumin                       -0.060829
# total_protiens                -0.310929
# dtype: float64

# %%
features=['asparate_aminotransferase','alamine_aminotransferase',
          'total_bilirubin','alkaline_phosphotase','direct_bilirubin']

# %%
for i in features:
  data[i]=data[i].apply('log1p')

# %%
data.isnull().sum()
# Out:
# age                           0
# gender                        0
# total_bilirubin               0
# direct_bilirubin              0
# alkaline_phosphotase          0
# alamine_aminotransferase      0
# asparate_aminotransferase     0
# total_protiens                0
# albumin                       0
# albumin_and_globulin_ratio    0
# outcome                       0
# dtype: int64

# %%
num_features=data.dtypes[data.dtypes!='object'].index
skew_features=data[num_features].skew().sort_values(ascending=False)
skew_features
# Out:
# total_bilirubin               1.731438
# direct_bilirubin              1.689599
# alamine_aminotransferase      1.470664
# alkaline_phosphotase          1.326397
# asparate_aminotransferase     1.246183
# albumin_and_globulin_ratio    1.004870
# outcome                       0.940320
# age                          -0.046597
# albumin                      -0.060829
# total_protiens               -0.310929
# dtype: float64

# %%
sns.pairplot(data, diag_kind='kde')
plt.show()

# %% [markdown]
# # We clearly observe that there is some features that are in strong linear relationship

# %%
minority = data[data.outcome==1]
majority = data[data.outcome==0]

print('Minority size:', minority.shape)
print('Majority size:', majority.shape)
# Out:
# Minority size: (164, 11)
# Majority size: (406, 11)

# %%
from sklearn.utils import resample
minority_upsample = resample(minority, replace=True, n_samples=majority.shape[0])
print('Minority upsampled size:', minority_upsample.shape)
# Out:
# Minority upsampled size: (406, 11)

# %%
data = pd.concat([minority_upsample, majority], axis=0)

# %% [markdown]
# # **MODELLING**

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['gender']=encoder.fit_transform(data['gender'])

# %%
data.head()
# Out:
#      age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 333   36       0         0.530628          0.182322              5.030438
# 480    7       1         0.405465          0.095310              5.866468
# 265    4       1         0.641854          0.182322              5.855072
# 283   18       1         0.832909          0.530628              5.758902
# 456   32       1         0.530628          0.182322              5.247024
#
#      alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 333                  3.091042                   3.258097             5.9
# 480                  3.367296                   3.951244             7.9
# 265                  3.433987                   3.555348             8.0
# 283                  2.397895                   3.091042             6.0
# 456                  3.135494                   3.784190             7.4
#
#      albumin  albumin_and_globulin_ratio  outcome
# ...

# %%
data['gender'].value_counts()
# Out:
# 1    604
# 0    208
# Name: gender, dtype: int64

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]
print(X.head(), y.head())
# Out:
#      age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 333   36       0         0.530628          0.182322              5.030438
# 480    7       1         0.405465          0.095310              5.866468
# 265    4       1         0.641854          0.182322              5.855072
# 283   18       1         0.832909          0.530628              5.758902
# 456   32       1         0.530628          0.182322              5.247024
#
#      alamine_aminotransferase  asparate_aminotransferase  total_protiens  \
# 333                  3.091042                   3.258097             5.9
# 480                  3.367296                   3.951244             7.9
# 265                  3.433987                   3.555348             8.0
# 283                  2.397895                   3.091042             6.0
# 456                  3.135494                   3.784190             7.4
#
#      albumin  albumin_and_globulin_ratio
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(X)
X_scale=pd.DataFrame(data=scaler.transform(X), columns=X.columns)

# %%
# Split the data into trainset and testset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scale,y, test_size=0.25, random_state=123)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (609, 10) (203, 10) (609,) (203,)

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(C=0.4)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.4)

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix,f1_score, roc_curve, roc_auc_score,auc

# %%
y_train_pred=model.predict(X_train)
accuracy_score(y_train, y_train_pred)
# Out:
# 0.7175697865353038

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.7192118226600985

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.60      0.66        91
#            1       0.72      0.81      0.76       112
#
#     accuracy                           0.72       203
#    macro avg       0.72      0.71      0.71       203
# weighted avg       0.72      0.72      0.72       203

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[55, 36],
#        [21, 91]])

# %% [markdown]
# # **K Nearest Neighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=12)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_train_predict=model.predict(X_train)

# %%
print(accuracy_score(y_train_predict, y_train))
print("...............................................................")
print(classification_report(y_train_predict,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predict,y_train))
# Out:
# 0.729064039408867
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.72       268
#            1       0.80      0.69      0.74       341
#
#     accuracy                           0.73       609
#    macro avg       0.73      0.73      0.73       609
# weighted avg       0.74      0.73      0.73       609
#
# ...............................................................
# [[209  59]
#  [106 235]]

# %%
y_test_predictions=model.predict(X_test)

# %%
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
# Out:
# 0.6748768472906403
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        91
#            1       0.71      0.71      0.71       112
#
#     accuracy                           0.67       203
#    macro avg       0.67      0.67      0.67       203
# weighted avg       0.67      0.67      0.67       203
#
# ...............................................................
# [[58 33]
#  [33 79]]

# %%
def elbow_method(k):
  test_error=[]
  for i in k:
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,y_train)
    predictions=model.predict(X_test)
    score=accuracy_score(y_test, predictions)
    test_error.append(score)
  return test_error

# %%
k=range(6, 30,2)
test=elbow_method(k)
j=0
for i in range(6,30,2):
  print(i, test[j])
  j+=1
# Out:
# 6 0.6847290640394089
# 8 0.7241379310344828
# 10 0.6748768472906403
# 12 0.6748768472906403
# 14 0.6699507389162561
# 16 0.6650246305418719
# 18 0.6945812807881774
# 20 0.6699507389162561
# 22 0.6896551724137931
# 24 0.6995073891625616
# 26 0.6798029556650246
# 28 0.6995073891625616

# %% [markdown]
# # **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 0.7110016420361248
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.53      0.86      0.65       195
#            1       0.90      0.64      0.75       414
#
#     accuracy                           0.71       609
#    macro avg       0.72      0.75      0.70       609
# weighted avg       0.78      0.71      0.72       609
#
# ...............................................................
# [[167  28]
#  [148 266]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
# Out:
# 0.7142857142857143
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.47      0.81      0.60        53
#            1       0.91      0.68      0.78       150
#
#     accuracy                           0.71       203
#    macro avg       0.69      0.75      0.69       203
# weighted avg       0.80      0.71      0.73       203
#
# ...............................................................
# [[ 43  10]
#  [ 48 102]]

# %% [markdown]
# # **Support Vector Machines**

# %%
from sklearn.svm import SVC, LinearSVC
model=SVC(C=0.4)

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=0.4)

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 0.7192118226600985
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.60      0.81      0.69       232
#            1       0.85      0.66      0.75       377
#
#     accuracy                           0.72       609
#    macro avg       0.72      0.74      0.72       609
# weighted avg       0.75      0.72      0.72       609
#
# ...............................................................
# [[188  44]
#  [127 250]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
# Out:
# 0.7142857142857143
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.57      0.73      0.64        71
#            1       0.83      0.70      0.76       132
#
#     accuracy                           0.71       203
#    macro avg       0.70      0.72      0.70       203
# weighted avg       0.74      0.71      0.72       203
#
# ...............................................................
# [[52 19]
#  [39 93]]

# %% [markdown]
# # **Linear SVC**

# %%
model=LinearSVC()

# %%
model.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 0.7093596059113301
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.62      0.77      0.69       252
#            1       0.81      0.66      0.73       357
#
#     accuracy                           0.71       609
#    macro avg       0.71      0.72      0.71       609
# weighted avg       0.73      0.71      0.71       609
#
# ...............................................................
# [[195  57]
#  [120 237]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
# Out:
# 0.7093596059113301
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.65        80
#            1       0.79      0.72      0.75       123
#
#     accuracy                           0.71       203
#    macro avg       0.70      0.71      0.70       203
# weighted avg       0.72      0.71      0.71       203
#
# ...............................................................
# [[56 24]
#  [35 88]]

# %% [markdown]
# # **Decision Trees**

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 1.0
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# ...............................................................
# [[315   0]
#  [  0 294]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
# Out:
# 0.8325123152709359
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80        81
#            1       0.89      0.82      0.85       122
#
#     accuracy                           0.83       203
#    macro avg       0.83      0.84      0.83       203
# weighted avg       0.84      0.83      0.83       203
#
# ...............................................................
# [[ 69  12]
#  [ 22 100]]

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 1.0
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# ...............................................................
# [[315   0]
#  [  0 294]]

# %%
# testing evaluaion
y_test_predictions=model.predict(X_test)
print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
print(roc_auc_score(y_test_predictions, y_test))
# Out:
# 0.8472906403940886
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82        86
#            1       0.88      0.85      0.86       117
#
#     accuracy                           0.85       203
#    macro avg       0.84      0.85      0.84       203
# weighted avg       0.85      0.85      0.85       203
#
# ...............................................................
# [[73 13]
#  [18 99]]
# 0.8474955277280859

# %% [markdown]
# # **XGboost**

# %%
pip install xgboost

# %%
from xgboost import XGBClassifier
model=XGBClassifier(random_state=123)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(random_state=123)

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 0.8899835796387521
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       272
#            1       0.96      0.84      0.89       337
#
#     accuracy                           0.89       609
#    macro avg       0.89      0.90      0.89       609
# weighted avg       0.90      0.89      0.89       609
#
# ...............................................................
# [[260  12]
#  [ 55 282]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)

print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
print("...............................................................")
print(roc_auc_score(y_test, y_test_predictions))
# Out:
# 0.8029556650246306
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        81
#            1       0.87      0.80      0.83       122
#
#     accuracy                           0.80       203
#    macro avg       0.80      0.80      0.80       203
# weighted avg       0.81      0.80      0.80       203
#
# ...............................................................
# [[66 15]
#  [25 97]]
# ...............................................................
# 0.7956730769230769

# %% [markdown]
# # **Extra Trees Classifier**

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
# training evaluation

y_train_predictions=model.predict(X_train)

print(accuracy_score(y_train_predictions, y_train))
print("...............................................................")
print(classification_report(y_train_predictions,y_train))
print("...............................................................")
print(confusion_matrix(y_train_predictions,y_train))
# Out:
# 1.0
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# ...............................................................
# [[315   0]
#  [  0 294]]

# %%
# testing evaluaion

y_test_predictions=model.predict(X_test)

print(accuracy_score(y_test_predictions, y_test))
print("...............................................................")
print(classification_report(y_test_predictions,y_test))
print("...............................................................")
print(confusion_matrix(y_test_predictions,y_test))
print("...............................................................")
print(roc_auc_score(y_test, y_test_predictions))
# Out:
# 0.8916256157635468
# ...............................................................
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        87
#            1       0.92      0.89      0.90       116
#
#     accuracy                           0.89       203
#    macro avg       0.89      0.89      0.89       203
# weighted avg       0.89      0.89      0.89       203
#
# ...............................................................
# [[ 78   9]
#  [ 13 103]]
# ...............................................................
# 0.8883928571428572

# %% [markdown]
# # **Model Evaluation and hyper parameter tuning**

# %%
from sklearn.model_selection import GridSearchCV, KFold
# Decision Trees
params = {
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [1,2,4,5],
    'min_samples_leaf': [1,2,4,5],
    'max_leaf_nodes': [4,10,20,50,None]
}

gs1 = GridSearchCV(DecisionTreeClassifier(), params,n_jobs=-1, cv=KFold(n_splits=3), scoring='roc_auc')
gs1.fit(X_train, y_train)

print('Best score:', gs1.best_score_)
print('Best score:', gs1.best_params_)
# Out:
# Best score: 0.767084139741379
# Best score: {'criterion': 'gini', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5}

# %%
# Random forest
params = {
    'n_estimators': [100, 200, 500],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [1,2,4,5],
    'min_samples_leaf': [1,2,4,5],
    'max_leaf_nodes': [4,10,20,50,None]
}

gs1 = GridSearchCV(RandomForestClassifier(n_jobs=-1), params, n_jobs=-1, cv=KFold(n_splits=3), scoring='roc_auc')
gs1.fit(X_train, y_train)

print('Best score:', gs1.best_score_)
print('Best score:', gs1.best_params_)
# Out:
# Best score: 0.8965307617449872
# Best score: {'criterion': 'gini', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# XGBoost
params = {
    'n_estimators': [100, 200, 500],
    'learning_rate': [0.01,0.05,0.1],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0, 0.5, 1],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [0.5, 1, 5],
    'base_score': [0.2, 0.5, 1]
}

gs2 = GridSearchCV(XGBClassifier(n_jobs=-1), params, n_jobs=-1, cv=KFold(n_splits=3), scoring='roc_auc')
gs2.fit(X_train, y_train)

print('Best score:', gs2.best_score_)
print('Best score:', gs2.best_params_)
# Out:
# Best score: 0.8603153745597815
# Best score: {'base_score': 0.2, 'booster': 'gbtree', 'gamma': 0, 'learning_rate': 0.1, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 0.5}

# %%
# Extra Tree Classifier
params = {
    'n_estimators': [100, 200, 500],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [1,2,4,5],
    'min_samples_leaf': [1,2,4,5],
    'max_leaf_nodes': [4,10,20,50,None]
}

gs3 = GridSearchCV(ExtraTreesClassifier(n_jobs=-1), params, n_jobs=-1, cv=KFold(n_splits=3), scoring='roc_auc')
gs3.fit(X_train, y_train)

print('Best score:', gs3.best_score_)
print('Best score:', gs3.best_params_)
# Out:
# Best score: 0.9102148388651132
# Best score: {'criterion': 'gini', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import VotingClassifier

# %%
model=gs1.best_estimator_
model.fit(X_train, y_train)
y_train_predictions = model.predict(X_train)
y_test_predictions = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_predictions))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_predictions))

print('Roc_auc score')
print('-------------------------------------------------------')
print(roc_auc_score(y_test, y_test_predictions))
print('')

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_predictions))


print("Accuracy Score")
print('-------------------------------------------------------')
print(accuracy_score(y_test, y_test_predictions))
# Out:
# RandomForestClassifier(n_jobs=-1)
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        91
#            1       0.85      0.87      0.86       112
#
#     accuracy                           0.84       203
#    macro avg       0.84      0.84      0.84       203
# weighted avg       0.84      0.84      0.84       203
#
# Roc_auc score
# -------------------------------------------------------
# 0.8396291208791209
#
# Confusion matrix
# ...

# %%
model=gs2.best_estimator_
model.fit(X_train, y_train)
y_train_predictions = model.predict(X_train)
y_test_predictions = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_predictions))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_predictions))

print('Roc_auc score')
print('-------------------------------------------------------')
print(roc_auc_score(y_test, y_test_predictions))
print('')

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_predictions))

print('-------------------------------------------------------')
print(accuracy_score(y_test, y_test_predictions))
# Out:
# XGBClassifier(base_score=0.2, n_estimators=500, n_jobs=-1, reg_lambda=0.5)
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        91
#            1       0.82      0.91      0.86       112
#
#     accuracy                           0.84       203
#    macro avg       0.85      0.83      0.84       203
# weighted avg       0.85      0.84      0.84       203
#
# Roc_auc score
# -------------------------------------------------------
# ...

# %%
model=gs3.best_estimator_
model.fit(X_train, y_train)
y_train_predictions = model.predict(X_train)
y_test_predictions = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_predictions))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_predictions))

print('Roc_auc score')
print('-------------------------------------------------------')
print(roc_auc_score(y_test, y_test_predictions))
print('')

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_predictions))

print('-------------------------------------------------------')
print(accuracy_score(y_test, y_test_predictions))
# Out:
# ExtraTreesClassifier(n_jobs=-1)
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       315
#            1       1.00      1.00      1.00       294
#
#     accuracy                           1.00       609
#    macro avg       1.00      1.00      1.00       609
# weighted avg       1.00      1.00      1.00       609
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88        91
#            1       0.92      0.88      0.89       112
#
#     accuracy                           0.89       203
#    macro avg       0.89      0.89      0.89       203
# weighted avg       0.89      0.89      0.89       203
#
# Roc_auc score
# -------------------------------------------------------
# 0.8880494505494505
#
# Confusion matrix
# ...

# %%
def thresholds(model, X_test, thresholds):
  return np.where(model.predict_proba(X_test)[:,1]>thresholds, 1, 0 )

# %%
for thr in np.arange(0,1.1,0.1):
  y_predict = thresholds(model, X_test, thr)
  print("The Threshold value: ",thr)
  print("The Confusion matrix:\n",confusion_matrix(y_test, y_predict))
  print("The Accuracy Score",accuracy_score(y_test, y_predict))
  print(".............................................")
# Out:
# The Threshold value:  0.0
# The Confusion matrix:
#  [[  2  89]
#  [  0 112]]
# The Accuracy Score 0.5615763546798029
# .............................................
# The Threshold value:  0.1
# The Confusion matrix:
#  [[ 30  61]
#  [  1 111]]
# The Accuracy Score 0.6945812807881774
# .............................................
# The Threshold value:  0.2
# The Confusion matrix:
#  [[ 41  50]
#  [  2 110]]
# The Accuracy Score 0.7438423645320197
# .............................................
# The Threshold value:  0.30000000000000004
# The Confusion matrix:
#  [[ 51  40]
#  [  3 109]]
# The Accuracy Score 0.7881773399014779
# .............................................
# The Threshold value:  0.4
# The Confusion matrix:
#  [[ 67  24]
#  [  8 104]]
# The Accuracy Score 0.8423645320197044
# .............................................
# The Threshold value:  0.5
# The Confusion matrix:
#  [[82  9]
#  [14 98]]
# The Accuracy Score 0.8866995073891626
# ...

# %%
print(roc_auc_score(y_test, y_test_predictions))
# Out:
# 0.8880494505494505

# %%
from sklearn.metrics import auc, roc_curve, roc_auc_score
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_test_predictions )
roc_auc = auc(false_positive_rate, true_positive_rate)
print (roc_auc)
# Out:
# 0.8880494505494505

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b', label='AUC = %0.2f' % roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
pd.crosstab(y_train, y_train_predictions)
# Out:
# col_0      0    1
# outcome
# 0        315    0
# 1          0  294

# %%
pd.crosstab(y_test,y_test_predictions)
# Out:
# col_0     0   1
# outcome
# 0        82   9
# 1        14  98

# %% [markdown]
# # **OBSERVATIONS**

# %% [markdown]
# 1.   Clearly it shows that The algorithms Random Forest, XGBoost and Extra Tree Classifier will give best accuracy and overfits the data.
